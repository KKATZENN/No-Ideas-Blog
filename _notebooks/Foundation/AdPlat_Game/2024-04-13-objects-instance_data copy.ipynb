# %% [raw]
# ---
# toc: true
# comments: true
# layout: post
# title: Instance Data HACKS
# description: Objects in JavaScript are a fundamental data type. Each Game Object, in the game, is a collections of instance data and methods. JavaScript Objects are used to store the states of a Game Objects.
# courses: { csse: {week: 19} }
# type: ccc
# ---

# %% [markdown]
# ## Hack
#
# Create and Manage objects hack
#
# 1. In this notebook combine concept of Object Literal and Object Instance.  Use Object Literal as an intiaizer for the Object Instance.
# 2. Make an array of Player object instances four or five, give them health and power, ie speed, strength, ...
#     * Make a game loop to cycle through each of the objects
#     * Each pass through the loop have a random object battle with all other objects using a random power
#     * Lower health by 1 on battle, lower health by 10 for loss
#     * Provide a leader board output each round
#     * Kill objects if their health goes to zero or less
#
# You can work with pair/trio, but each of you should have a different concept
#
# #### Hacks

# %%
# %%js
#
# const player1 = {
#     name: "Edaward",
#     health: 100,
#     greeting: function() {
#         return "Hey, Im " + this.name;
#     },
#     attack: function() {
#
#     let target = Math.floor(Math.random() * 3) + 1;
#     let meaniehead;
#
#             if(target = 1) {
#                 let meaniehead = player2;
#             } else if(target = 2) {
#                 let meaniehead = player3;
#             } else {
#                 let meaniehead = player4;
#             }
#
#         meaniehead.health -= Math.floor(Math.random() * 20);
#         console.log(`Edaward attacked ${player1.meaniehead}`);
#         console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#     },
#     specialpower: function(){
#         let hulkSmash = Math.random();
#
#         if(hulkSmash >= 0.6) {
#             player2.health -=10
#             player3.health -=10
#             player4.health -=10
#             console.log("Edaward smashes the area around them!");
#         }
#     },
#     death: function() {
#         if(this.health <= 0) {
#             deadplayers += 1;
#             console.log("Edaward has died!");
#             clearInterval(intervalId);
#             return;
#         }
#     }
# };
#
# const player2 = {
#     name: "Khristan",
#     health: 100,
#     greeting: function() {
#         return "I, " + this.name + " shall be the victor!"
#     },
#     attack: function() {
#
#     let target = Math.floor(Math.random() * 3) + 1;
#     let meaniehead;
#
#             if(target === 1) {
#                 let meaniehead = player1;
#             } else if(target === 2) {
#                 let meaniehead = player3;
#             } else {
#                 let meaniehead = player4;
#             }
#
#         meaniehead.health -= Math.floor(Math.random() * 20);
#         console.log(`Khristan attacked ${player2.meaniehead}`);
#         console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#     },
#     specialpower: function(){
#         let passiveHeal = Math.random();
#
#         if(passiveHeal >= 0.8) {
#             this.health += 20;
#             console.log("Khristan has healed 20 hp!");
#             console.log(`${player2.name} now has ${player2.health} hp`);
#         }
#     },
#     death: function() {
#         if(this.health <= 0) {
#             deadplayers += 1;
#             console.log("Khristan has perished!");
#             clearInterval(intervalId);
#             return;
#         }
#     }
# };
#
# const player3 = {
#     name: "Natanial",
#     health: 100,
#     greeting: function() {
#         return "My name is " + this.name + " just kill me already";
#     },
#     attack: function() {
#
#     let target = Math.floor(Math.random() * 3) + 1;
#     let meaniehead;
#
#             if(target === 1) {
#                 let meaniehead = player1;
#             } else if(target === 2) {
#                 let meaniehead = player4;
#             } else {
#                 let meaniehead = player2;
#             }
#
#         meaniehead.health -= Math.floor(Math.random() * 20);
#         console.log(`Natanial attacked ${player3.meaniehead}`);
#         console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#     },
#     specialpower: function(){
#         let coinflip = Math.random();
#
#         if(coinflip >= 0.5) {
#             player3.attack;
#             console.log("Natanial has attacked twice in one swing!");
#             console.log(`Natanial attacked ${player3.meaniehead}`);
#             console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#         }
#     },
#     death: function() {
#
#         if(this.health <= 0) {
#
#             deadplayers += 1;
#             console.log("Natanial has been released from this mortal prison!");
#             clearInterval(intervalId);
#             return;
#         }
#     }
# };
#
# const player4 = {
#     name: "Gehova",
#     health: 100,
#     greeting: function() {
#         return "I, " + this.name + " have been chosen by god to do their bidding."
#     },
#     attack: function() {
#
#     let target = Math.floor(Math.random() * 3) + 1;
#     let meaniehead;
#
#             if(target === 1) {
#                 let meaniehead = player1;
#             } else if(target === 2) {
#                 let meaniehead = player3;
#             } else {
#                 let meaniehead = player4;
#             }
#
#         meaniehead.health -= Math.floor(Math.random() * 20);
#         console.log(`Gehova attacked ${player4.meaniehead}`);
#         console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#     },
#     specialpower: function(){
#         let critical = Math.random();
#
#         if(critical >= 0.65) {
#             meaniehead.health -= 14;
#             console.log("Gehova has landed a critical hit!");
#             console.log(`${meaniehead.name} now has ${meaniehead.health} hp`);
#         }
#     },
#     death: function() {
#         if(this.health <= 0) {
#             deadplayers += 1;
#             console.log("Gehova has acsended!");
#             clearInterval(intervalId);
#             return;
#         }
#     }
# };
#
# let players = [player1,player2,player3,player4].filter(player => player.health > 0);
# let deadplayers = 0;
#
# function gameLoop() {
#
#     if (deadplayers < 3) {
#         for(let i = 0; i < 5; i++) {
#             let roundNumber = 1;
#
#             if(i++) {
#                 roundNumber += 1;
#             }
#             console.log(`-- Round ${roundNumber} --`);
#
#             player1.attack();
#             player1.specialpower();
#             player2.attack();
#             player2.specialpower();
#             player3.attack();
#             player3.specialpower();
#             player4.attack();
#             player4.specialpower();
#
#             player1.death();
#             player2.death();
#             player3.death();
#             player4.death();
#
#             console.log("-- Leaderboard --");
#             console.log(`${player1.name}, ${player1.health} hp`);
#             console.log(`${player2.name}, ${player2.health} hp`);
#             console.log(`${player3.name}, ${player3.health} hp`);
#             console.log(`${player4.name}, ${player4.health} hp`);
#
#         }
#     } else if(deadplayers === 3) {
#         console.log(`${players} is the winner!`);
#         return;
#     } else if (deadplayers <= 2) {
#         i -= 1;
#     } else {
#         console.log("All players have died!");
#         return;
#     }
#
# }
#
# gameLoop();
